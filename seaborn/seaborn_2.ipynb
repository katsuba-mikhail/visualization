# %% [markdown]
# # [Введение в визуализацию данных с Seaborn](https://nagornyy.me/courses/data-science/intro-to-seaborn/)

# %% [markdown]
# ## Импорт

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %% [markdown]
# ## Набор данных

# %% [markdown]
# Используется встроенный [набор данных о чаевых](https://github.com/mwaskom/seaborn-data/blob/master/tips.csv)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Визуализация категориальных данных

# %% [markdown]
# ## barplot

# %% [markdown]
# По умолчанию эта функция — среднее.

# %%
sns.barplot(x='sex', y='total_bill', data=tips)

# %% [markdown]
# Эту функцию можно изменить в аргументе `estimator`.
# Здесь мы считаем стандартное отклоенение.

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=len)

# %% [markdown]
# ## countplot

# %% [markdown]
# Cчитает количество значений в каждой категории.

# %%
sns.countplot(x='sex', data=tips)

# %% [markdown]
# **Промежуточное задание 1.** Постройте при помощи barplot точно также график, как с помощью countplot.

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=len)

# %% [markdown]
# ## boxplot

# %%
sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow')

# %%
sns.boxplot(data=tips, palette='rainbow', orient='h')

# %% [markdown]
# Можно ввести в график третье измерение:

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker", 
            data=tips, palette='coolwarm')

# %% [markdown]
# ## violinplot

# %%
sns.violinplot(x="day", y="total_bill", data=tips, palette='rainbow')

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", palette='Set1')

# %%
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", 
               split=True, palette='Set1')

# %% [markdown]
# ## stripplot

# %%
sns.stripplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# По умолчанию точки рассеяны по параметру `jitter`.

# %%
sns.stripplot(x="day", y="total_bill", data=tips, jitter=False)

# %%
sns.stripplot(x="day", y="total_bill", data=tips, 
              jitter=True, hue="sex", palette='Set1')

# %% [markdown]
# Разделение подкатегорий через `dodge`.

# %%
sns.stripplot(x="day", y="total_bill", data=tips, hue="sex",
              jitter=True, palette='Set1', dodge=True)

# %% [markdown]
# ## swarmplot

# %% [markdown]
# Без наложения точек.

# %%
plt.figure(figsize=(7, 5))
sns.swarmplot(x="day", y="total_bill", hue="sex", data=tips,
              palette='Set1', dodge=True, size=5)

# %% [markdown]
# Возможно комбинирование графиков

# %%
sns.violinplot(x="tip", y="day", data=tips, palette='rainbow')
sns.swarmplot(x="tip", y="day", data=tips, color='blue', size=3)

# %% [markdown]
# ## catplot (factorplot)

# %%
sns.catplot(x="sex", y="total_bill", data=tips, kind='bar')

# %%
sns.factorplot(x="sex", y="total_bill", data=tips, kind='bar')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
