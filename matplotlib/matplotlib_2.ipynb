# %% [markdown]
# # [Matplotlib. Урок 2. Работа с инструментом pyplot](https://devpractice.ru/matplotlib-lesson-2-work-with-pyplot/)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Основы

# %%
plt.plot()
# Out:
# []

# %% [markdown]
# Координаты [x1, y1, x2, y2, ..., xn, yn]

# %%
plt.plot([1, 7, 3, 5, 11, 1])

# %% [markdown]
# Координаты [x1, x2, ..., xn], [y1, y2, ..., yn]

# %%
plt.plot([1, 5, 10, 15, 20], [1, 7, 3, 5, 11])

# %% [markdown]
# ## Тектовые надписи

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]

plt.plot(x, y, label='steel price', color='red')
plt.title('Chart price', fontsize=17, fontweight='extra bold', loc='center')
plt.xlabel('Day', fontsize=15, color='blue', labelpad=10, fontstyle='oblique',
           fontweight='semibold')
plt.ylabel('Price', fontsize=12, color='blue')
plt.legend()
plt.grid(True)
plt.text(15, 4, 'grow up!')
# Out:
# Text(15, 4, 'grow up!')

# %% [markdown]
# ## Пунктир

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]
plt.plot(x, y, '--')

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]
line = plt.plot(x, y)
plt.setp(line, linestyle='--')
# Out:
# [None]

# %%
x = [1, 5, 10, 15, 20]
y1 = [1, 7, 3, 5, 11]
y2 = [i*1.2 + 1 for i in y1]
y3 = [i*1.2 + 1 for i in y2]
y4 = [i*1.2 + 1 for i in y3]
plt.plot(x, y1, '-', x, y2, '--', x, y3, '-.', x, y4, ':')
# Out:
# [<matplotlib.lines.Line2D at 0x7fb029190090>,
#  <matplotlib.lines.Line2D at 0x7fb029190290>,
#  <matplotlib.lines.Line2D at 0x7fb029190450>,
#  <matplotlib.lines.Line2D at 0x7fb029190610>]

# %%
plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)
plt.plot(x, y4)

# %% [markdown]
# ## Цвета графиков

# %% [markdown]
# Задание цвета линии графика производится через параметр color (или c, если использовать сокращенный вариант). Значение может быть представлено в одном из следующих форматов:
#
# * RGB или RGBA кортеж значений с плавающей точкой в диапазоне [0, 1] (пример: (0.1, 0.2, 0.3)
# * RGB или RGBA значение в hex формате (пример: ‘#0a0a0a’)
# * строковое представление числа с плавающей точкой в диапазоне [0, 1] (определяет цвет в шкале серого) (пример: ‘0.7’)
# * символ из набора {‘b’, ‘g’, ‘r’, ‘c’, ‘m’, ‘y’, ‘k’, ‘w’}
# * имя цвета из палитры X11/CSS4
# * цвет из палитры xkcd(https://xkcd.com/color/rgb/), должен начинаться с префикса ‘xkcd:’
# * цвет из набора  Tableau Color (палитра T10), должен начинаться с префикса ‘tab:’
# Если цвет задается с помощью символа из набора {‘b’, ‘g’, ‘r’, ‘c’, ‘m’, ‘y’, ‘k’, ‘w’}, то он может быть совмещен со стилем линии в рамках параметра fmt функции plot().
#
# Например штриховая красная линия будет задаваться так: ‘–r’, а штрих пунктирная зеленая так ‘-.g’

# %%
x = [1, 3, 5, 7, 9]
y1 = [1, 9, 5, 3, 7]
y2 = [i*1.2 + 1 for i in y1]

plt.plot(x, y1, '--r', x, y2, '-.m')
# Out:
# [<matplotlib.lines.Line2D at 0x7fb02907c410>,
#  <matplotlib.lines.Line2D at 0x7fb02907c5d0>]

# %% [markdown]
# ## Типы графиков

# %%
x = [1, 5, 10, 15, 20]
y1 = [1, 7, 3, 5, 11]
y2 = [i*1.2 + 1 for i in y1]
y3 = [i*1.2 + 1 for i in y2]
plt.plot(x, y1, 'ro')
plt.plot(x, y2, 'bx')
plt.plot(x, y3, 'g^')

# %%
## Разные поля

# %%
x = [1, 5, 10, 15, 20]
y1 = [1, 7, 3, 5, 11]
y2 = [i*1.2 + 1 for i in y1]
y3 = [i*1.2 + 1 for i in y2]
y4 = [i*1.2 + 1 for i in y3]

plt.figure(figsize=(12, 7))

plt.subplot(2, 2, 1)
plt.plot(x, y1, 'b-x')
plt.subplot(2, 2, 2)
plt.plot(x, y2, 'r--o')
plt.subplot(2, 2, 3)
plt.plot(x, y3, 'k-.*')
plt.subplot(2, 2, 4)
plt.plot(x, y4, ':D')

# %% [markdown]
# Без подсчёта номера графика

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 7))
ax[0, 0].plot(x, y1, ':d')
ax[0, 1].plot(x, y2, ':s')
ax[1, 0].plot(x, y3, ':h')
ax[1, 1].plot(x, y4, '3')
