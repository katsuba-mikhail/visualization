# %% [markdown]
# # [Matplotlib. Урок 3.2. Настройка графиков. Компоновка графиков](https://devpractice.ru/matplotlib-lesson-3-2-plot-layout/)

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %matplotlib inline

# %% [markdown]
# ## Инструмент GridSpec

# %%
x = np.arange(10)
y1 = np.random.permutation(10)
y2 = np.random.permutation(10)

fg = plt.figure(figsize=(7, 3), constrained_layout=True)
gs = gridspec.GridSpec(ncols=2, nrows=1, figure=fg)

fig_ax_1 = fg.add_subplot(gs[0, 0])
plt.plot(x, y1)

fix_ax_2 = fg.add_subplot(gs[0, 1])
plt.plot(x, y2)

# %%
x = np.arange(10)
y1 = np.random.permutation(10)
y2 = np.random.permutation(10)
y3 = np.random.permutation(10)

fg = plt.figure(figsize=(9, 4), constrained_layout=True)
gs = fg.add_gridspec(2, 2)

fig_ax_1 = fg.add_subplot(gs[0, :])
plt.plot(x, y1)

fig_ax_2 = fg.add_subplot(gs[1, 0])
plt.plot(x, y2)

fig_ax_3 = fg.add_subplot(gs[1, 1])
plt.plot(x, y3)

# %%
x = np.arange(10)
y1 = np.random.permutation(10)
y2 = np.random.permutation(10)
y3 = np.random.permutation(10)
y4 = np.random.permutation(10)
y5 = np.random.permutation(10)
y6 = np.random.permutation(10)
y7 = np.random.permutation(10)
y8 = np.random.permutation(10)

fg = plt.figure(figsize=(9, 9), constrained_layout=True)
gs = fg.add_gridspec(5, 5)

fig_ax_1 = fg.add_subplot(gs[0, :3])
fig_ax_1.set_title('gs[0, :3]')
plt.plot(x, y1, color=np.random.rand(3))

fig_ax_2 = fg.add_subplot(gs[0, 3:])
fig_ax_2.set_title('gs[0, 3:]')
plt.plot(x, y2, color=np.random.rand(3))

fig_ax_3 = fg.add_subplot(gs[1:, 0])
fig_ax_3.set_title('gs[1:, 0]')
plt.plot(x, y3, color=np.random.rand(3))

fig_ax_4 = fg.add_subplot(gs[1:, 1])
fig_ax_4.set_title('gs[1:, 1]')
plt.plot(x, y4, color=np.random.rand(3))

fig_ax_5 = fg.add_subplot(gs[1, 2:])
fig_ax_5.set_title('gs[1, 2:]')
plt.plot(x, y5, color=np.random.rand(3))

fig_ax_6 = fg.add_subplot(gs[2:4, 2])
fig_ax_6.set_title('gs[2:4, 2]')
plt.plot(x, y6, color=np.random.rand(3))

fig_ax_7 = fg.add_subplot(gs[2:4, 3:])
fig_ax_7.set_title('gs[2:4, 3:]')
plt.plot(x, y7, color=np.random.rand(3))

fig_ax_8 = fg.add_subplot(gs[4, 3:])
fig_ax_8.set_title('gs[4, 3:]')
plt.plot(x, y8, color=np.random.rand(3))

# %%
x = np.arange(10)
y1 = np.random.permutation(10)
y2 = np.random.permutation(10)
y3 = np.random.permutation(10)
y4 = np.random.permutation(10)

fg = plt.figure(figsize=(5, 5), constrained_layout=True)
widths= [1, 3]
heights = [2, 0.7]

gs = fg.add_gridspec(ncols=2, nrows=2, 
                     width_ratios=widths, height_ratios=heights)

fig_ax_1 = fg.add_subplot(gs[0, 0])
fig_ax_1.set_title('w:1, h:2')
plt.plot(x, y1, color=np.random.rand(3))

fig_ax_2 = fg.add_subplot(gs[0, 1])
fig_ax_2.set_title('w:3, h:2')
plt.plot(x, y2, color=np.random.rand(3))

fig_ax_3 = fg.add_subplot(gs[1, 0])
fig_ax_3.set_title('w:1, h:0,7')
plt.plot(x, y3, color=np.random.rand(3))

fig_ax_4 = fg.add_subplot(gs[1, 1])
fig_ax_4.set_title('w:3, h:0,7')
plt.plot(x, y4, color=np.random.rand(3))
