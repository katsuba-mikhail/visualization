# %% [markdown]
# # [Matplotlib. Урок 4.1. Визуализация данных. Линейный график](https://devpractice.ru/matplotlib-lesson-4-1-viz-linear-chart/)

# %% [markdown]
# ## Импорт

# %%
import numpy as np
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Построение графика

# %% [markdown]
# <table>
# <tbody>
# <tr>
# <td><span style="color: #000000;"><b>Свойство</b></span></td>
# <td><span style="color: #000000;"><b>Тип</b></span></td>
# <td><span style="color: #000000;"><b>Описание</b></span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">alpha</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">float</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Прозрачность</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">color </span></i><span style="font-weight: 400;">или </span><i><span style="font-weight: 400;">c</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">color</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Цвет</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">fillstyle</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">{‘full’, ‘left’, ‘right’, ‘bottom’, ‘top’, ‘none’}</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Стиль заливки</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">label</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">object</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Текстовая метка</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">linestyle </span></i><span style="font-weight: 400;">или </span><i><span style="font-weight: 400;">ls</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">{‘-‘, ‘–‘, ‘-.’, ‘:’, ”, (offset, on-off-seq), …}</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Стиль линии</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">linewidth </span></i><span style="font-weight: 400;">или </span><i><span style="font-weight: 400;">lw</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">float</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Толщина линии</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">marker</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">matplotlib.markers</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Стиль маркера</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">markeredgecolor </span></i><span style="font-weight: 400;">или </span><i><span style="font-weight: 400;">mec</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">color</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Цвет границы маркера</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">markeredgewidth </span></i><span style="font-weight: 400;">или </span><i><span style="font-weight: 400;">mew</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">float</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Толщина границы маркера</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">markerfacecolor </span></i><span style="font-weight: 400;">или </span><i><span style="font-weight: 400;">mfc</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">color</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Цвет заливки маркера</span></td>
# </tr>
# <tr>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">markersize </span></i><span style="font-weight: 400;">или </span><i><span style="font-weight: 400;">ms</span></i></span></td>
# <td><span style="color: #000000;"><i><span style="font-weight: 400;">float</span></i></span></td>
# <td><span style="font-weight: 400; color: #000000;">Размер маркера</span></td>
# </tr>
# </tbody>
# </table>

# %%
x = np.arange(10)
y1 = np.random.permutation(10)
y2 = np.random.permutation(10)

plt.figure(figsize=(12, 7))

plt.plot(x, y1, 'o-r', alpha=0.7, label='first', lw=5, mec='b', mew=2, ms=10)
plt.plot(x, y2, 'v-.g', label='second', mec='r', lw=2, mew=2, ms=12)
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Заливка области между графиком и осью

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x * np.pi)

plt.plot(x, y, c = 'r')
plt.fill_between(x, y)

# %%
plt.plot(x, y, c = 'r')
plt.fill_between(x, y, where= (y > 0.75) | (y < -0.75))

# %%
plt.plot(x, y, c='m')
plt.fill_between(x, y, where = (y > 0))

# %%
plt.plot(x, y, c='m')
plt.fill_between(x, 0.5, y, where=(y>=0.5))

# %%
plt.plot(x, y, c='m')
plt.grid()
plt.fill_between(x, y, 1)

# %%
plt.plot(x, y, c='m')
plt.grid()
plt.fill_between(x, y, where=(y>=0), color='b', alpha=0.3)
plt.fill_between(x, y, where=(y<=0), color='r', alpha=0.3)

# %% [markdown]
# ## Настройка маркировки графиков

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [7, 6, 5, 4, 5, 6, 7]

plt.plot(x, y, marker='o', c='m')

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x * np.pi)

plt.plot(x, y, marker='o', c='b')

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x * np.pi)

m_ev_case = [None, 10, (100, 30), slice(100, 400, 15), [0, 100, 200, 300], 
             [10, 50, 100]]

fig, ax = plt.subplots(2, 3, figsize=(10, 7))             
axs = [ax[i, j] for i in range(2) for j in range(3)]

for i, case in enumerate(m_ev_case):
    axs[i].set_title(str(case))
    axs[i].plot(x, y, 'o', ls='-', ms=7, markevery=case)

# %% [markdown]
# ## Обрезка графика

# %%
x = np.arange(0.0, 5, 0.01)
y = np.cos(x * np.pi)

y_masked = np.ma.masked_where(y < -0.5, y)

plt.ylim(-1, 1)
plt.plot(x, y_masked, linewidth=3)
